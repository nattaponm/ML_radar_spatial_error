# %% [markdown]
# # สร้างชื่อลิสต์ชื่อไฟล์รายชั่วโมงที่ต้องการโมเสค นำไปเก็บไว้ในโฟลเดอร์ ./0variables_mosaic/

# %%
import os
import re

def extract_timestamps(input_path):
    timestamp_pattern = re.compile(r'(\d{10})')  # Matches YYYYMMDDhh
    timestamp_set = set()
    
    print(f"Scanning directory: {input_path}")
    for station in os.listdir(input_path):
        station_path = os.path.join(input_path, station)
        if os.path.isdir(station_path):
            print(f"Scanning station directory: {station}")
            for filename in os.listdir(station_path):
                print(f"  Processing file: {filename}")
                match = timestamp_pattern.search(filename)
                if match:
                    timestamp = match.group(1)
                    print(f"    Found timestamp: {timestamp}")
                    timestamp_set.add(timestamp)
                else:
                    print(f"    No timestamp found in filename: {filename}")
    
    timestamp_list = sorted(list(timestamp_set))
    print(f"Total unique timestamps found: {len(timestamp_list)}")
    return timestamp_list

def save_timestamp_list(timestamp_list, output_file):
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    with open(output_file, 'w') as f:
        for timestamp in timestamp_list:
            f.write(f"{timestamp}\n")
    print(f"Timestamp list saved to {output_file}")

def read_timestamp_list(input_file):
    with open(input_file, 'r') as f:
        return [line.strip() for line in f]

# Set paths
input_path = '../1data/0radar/0Mosaic_MultiHourly_Sentihn/0_3hours/'
output_file = './0variables_mosaic/mos_hourly_times.txt'

# Generate and save timestamp list
timestamps = extract_timestamps(input_path)
save_timestamp_list(timestamps, output_file)
print(f"Generated {len(timestamps)} timestamps")

# Read the list back and print for verification
mos_times = read_timestamp_list(output_file)
print(f"Read {len(mos_times)} timestamps from file")
print("First few timestamps:", mos_times[:5])
if len(mos_times) > 5:
    print("Last few timestamps:", mos_times[-5:])
# Out:
# Scanning directory: ../1data/0radar/0Mosaic_MultiHourly_Sentihn/0_3hours/
# Scanning station directory: CHN
#   Processing file: CHN240@201807171100.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CHN240@201807171115.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CHN240@201807171130.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CHN240@201807171145.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CHN240@201807171200.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CHN240@201807171215.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CHN240@201807171230.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CHN240@201807171300.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: CHN240@201807171315.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: CHN240@201807171330.uf.bz2
#     Found timestamp: 2018071713
# Scanning station directory: CRI
#   Processing file: CRI240@201807171100.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CRI240@201807171115.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CRI240@201807171130.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CRI240@201807171145.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: CRI240@201807171200.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CRI240@201807171215.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CRI240@201807171230.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CRI240@201807171245.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: CRI240@201807171300.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: CRI240@201807171315.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: CRI240@201807171330.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: CRI240@201807171345.uf.bz2
#     Found timestamp: 2018071713
# Scanning station directory: LMP
#   Processing file: LMP240@201807171115.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: LMP240@201807171130.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: LMP240@201807171145.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: LMP240@201807171200.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: LMP240@201807171215.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: LMP240@201807171230.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: LMP240@201807171245.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: LMP240@201807171300.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: LMP240@201807171315.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: LMP240@201807171330.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: LMP240@201807171345.uf.bz2
#     Found timestamp: 2018071713
# Scanning station directory: PHS
#   Processing file: PHS240@201807171100.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: PHS240@201807171115.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: PHS240@201807171130.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: PHS240@201807171145.uf.bz2
#     Found timestamp: 2018071711
#   Processing file: PHS240@201807171200.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: PHS240@201807171215.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: PHS240@201807171230.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: PHS240@201807171245.uf.bz2
#     Found timestamp: 2018071712
#   Processing file: PHS240@201807171300.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: PHS240@201807171315.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: PHS240@201807171330.uf.bz2
#     Found timestamp: 2018071713
#   Processing file: PHS240@201807171345.uf.bz2
#     Found timestamp: 2018071713
# Total unique timestamps found: 3
# Timestamp list saved to ./0variables_mosaic/mos_hourly_times.txt
# Generated 3 timestamps
# Read 3 timestamps from file
# First few timestamps: ['2018071711', '2018071712', '2018071713']
